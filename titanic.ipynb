# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\shwet\\Downloads\\Titanic Dataset (5).csv")

# %% [markdown]
# ##Data Pre-Processing

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.shape
# Out:
# (418, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.fillna(df.mode().iloc[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
pd.get_dummies(df, columns=['Sex']) #One hot encoding
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name       Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  34.50000      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.00000      1      0
# 2                       Myles, Mr. Thomas Francis  62.00000      0      0
# 3                                Wirz, Mr. Albert  27.00000      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.00000      1      1
# ..                                            ...       ...    ...    ...
# ...

# %%
df['Sex'] = df['Sex'].map({'male':1, 'female':0}) #Label encoding

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                              Wirz, Mr. Albert    1  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
#
#     Ticket     Fare            Cabin Embarked
# 0   330911   7.8292  B57 B59 B63 B66        Q
# 1   363272   7.0000  B57 B59 B63 B66        S
# 2   240276   9.6875  B57 B59 B63 B66        Q
# 3   315154   8.6625  B57 B59 B63 B66        S
# 4  3101298  12.2875  B57 B59 B63 B66        S

# %%
pd.get_dummies(df, columns=['Embarked']) #One hot encoding
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    1  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  47.00000      1
# 2                       Myles, Mr. Thomas Francis    1  62.00000      0
# 3                                Wirz, Mr. Albert    1  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.00000      1
# ..                                            ...  ...       ...    ...
# ...

# %%
print(df['Embarked'].unique())
# Out:
# ['Q' 'S' 'C']

# %%
df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2}) #Label encoding

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                              Wirz, Mr. Albert    1  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
#
#     Ticket     Fare            Cabin  Embarked
# 0   330911   7.8292  B57 B59 B63 B66         2
# 1   363272   7.0000  B57 B59 B63 B66         0
# 2   240276   9.6875  B57 B59 B63 B66         2
# 3   315154   8.6625  B57 B59 B63 B66         0
# 4  3101298  12.2875  B57 B59 B63 B66         0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex       Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  0.334993      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    0  1.325530      1      0
# 2                     Myles, Mr. Thomas Francis    1  2.514175      0      0
# 3                              Wirz, Mr. Albert    1 -0.259330      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0 -0.655545      1      1
#
#     Ticket      Fare            Cabin  Embarked
# 0   330911 -0.498407  B57 B59 B63 B66         2
# 1   363272 -0.513274  B57 B59 B63 B66         0
# 2   240276 -0.465088  B57 B59 B63 B66         2
# 3   315154 -0.483466  B57 B59 B63 B66         0
# 4  3101298 -0.418471  B57 B59 B63 B66         0

# %% [markdown]
# ##EDA

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Histogram
sns.histplot(df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.hist(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
#Box plot
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=df['Parch'])
# Out:
# <Axes: xlabel='Parch'>

# %%
sns.boxplot(x=df['SibSp'])
# Out:
# <Axes: xlabel='SibSp'>

# %%
#Scatter plot
sns.scatterplot(x=df['Age'], y=df['Fare'])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x=df['Parch'], y=df['Fare'])
# Out:
# <Axes: xlabel='Parch', ylabel='Fare'>

# %%
sns.scatterplot(x=df['SibSp'], y=df['Fare'])
# Out:
# <Axes: xlabel='SibSp', ylabel='Fare'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df.select_dtypes(include='number').corr(),
            annot=True,
            cmap='coolwarm')

plt.show()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex       Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  0.334993      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    0  1.325530      1      0
# 2                     Myles, Mr. Thomas Francis    1  2.514175      0      0
# 3                              Wirz, Mr. Albert    1 -0.259330      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0 -0.655545      1      1
#
#     Ticket      Fare            Cabin  Embarked
# 0   330911 -0.498407  B57 B59 B63 B66         2
# 1   363272 -0.513274  B57 B59 B63 B66         0
# 2   240276 -0.465088  B57 B59 B63 B66         2
# 3   315154 -0.483466  B57 B59 B63 B66         0
# 4  3101298 -0.418471  B57 B59 B63 B66         0

# %% [markdown]
# ##Feature Engineering

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

df['IsAlone'] = 0
df.loc[df['FamilySize'] == 1, 'IsAlone'] = 1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    1  0.334993      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  1.325530      1
# 2                       Myles, Mr. Thomas Francis    1  2.514175      0
# 3                                Wirz, Mr. Albert    1 -0.259330      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0 -0.655545      1
# ..                                            ...  ...       ...    ...
# ...

# %% [markdown]
# #Feature Selections

# %%
df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked  \
# 0         0       3    1  0.334993      0      0 -0.498407         2
# 1         1       3    0  1.325530      1      0 -0.513274         0
# 2         0       2    1  2.514175      0      0 -0.465088         2
# 3         0       3    1 -0.259330      0      0 -0.483466         0
# 4         1       3    0 -0.655545      1      1 -0.418471         0
#
#    FamilySize  IsAlone
# 0           1        1
# 1           2        0
# 2           1        1
# 3           1        1
# 4           3        0
